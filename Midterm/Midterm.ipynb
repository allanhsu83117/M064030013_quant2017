# %%
import ffn
# %matplotlib inline
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import pickle
import talib
from talib import MA_Type
import requests
import csv
import io
import matplotlib.pyplot as plt

# %%
# 讀出預先下載好的股價資料
with open('stockdata', 'rb') as f:
    data = pickle.load(file=f)

# %% [markdown]
# # Q1. 畫出 Diamond Shape

# %%
#菱形
def diamond(h):
    for i in range(h):
        print(" "*(h-i)+"*"*(i)*2+"*")
    for j in range(h-1):
        print(" "*(j+2)+"*"*(h-j-2)*2+"*")

diamond(5)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
#   *******
#    *****
#     ***
#      *

# %% [markdown]
# # Q2. 刪除重複性資料
#
# 從 symbols01.txt 跟 symbols02.txt 讀入兩組股票代號，合併兩組代號，輸出一份無重複的股票代號到 symbols03.txt。

# %%
with open('symbols01.txt','r') as f:
    symbols_01=f.read()
    symbols_01=symbols_01.strip().split("\n")
    set_01=set(symbols_01)

# %%
with open('symbols02.txt','r') as f:
    symbols_02=f.read()
    symbols_02=symbols_02.strip().split("\n")
    set_02=set(symbols_02)

# %%
set_03 = (set_01 | set_02) - (set_01 & set_02)
symbols03 = list(set_03)
set_03 & (set_01 & set_02)
# Out:
# set()

# %%
with open('symbols03.txt','w') as f:
    for symbol in symbols03:
        f.write(symbol.strip().upper()+"\n")

# %% [markdown]
# # Q3. 下載台灣上市公司基本資料

# %% [markdown]
# 寫一個程式從 [http://dts.twse.com.tw/opendata/t187ap03_L.csv](http://dts.twse.com.tw/opendata/t187ap03_L.csv) 下載台灣上市公司基本資料，並輸出成 pandas dataframe。

# %%
r = requests.get("http://dts.twse.com.tw/opendata/t187ap03_L.csv")
r.encoding="big5"
com = r.text.split("\r\n")

com = io.StringIO(r.text)
TSE_com = pd.read_csv(com, skiprows=1,index_col=False)
TSE_com
# Out:
#          公司代號              公司名稱       產業別  \
# 0        1101        台灣水泥股份有限公司      水泥工業
# 1        1102        亞洲水泥股份有限公司      水泥工業
# 2        1103        嘉新水泥股份有限公司      水泥工業
# 3        1104        環球水泥股份有限公司      水泥工業
# 4        1108        幸福水泥股份有限公司      水泥工業
# 5        1109        信大水泥股份有限公司      水泥工業
# 6        1110        東南水泥股份有限公司      水泥工業
# 7        1201      味全食品工業股份有限公司      食品工業
# 8        1203          味王股份有限公司      食品工業
# 9        1210      大成長城企業股份有限公司      食品工業
# 10       1213       大西洋飲料股份有限公司      食品工業
# 11       1215      台灣卜蜂企業股份有限公司      食品工業
# 12       1216        統一企業股份有限公司      食品工業
# 13       1217         愛之味股份有限公司      食品工業
# 14       1218        泰山企業股份有限公司      食品工業
# 15       1219        福壽實業股份有限公司      食品工業
# 16       1220        台榮產業股份有限公司      食品工業
# 17       1225        福懋油脂股份有限公司      食品工業
# 18       1227        佳格食品股份有限公司      食品工業
# 19       1229        聯華實業股份有限公司      食品工業
# 20       1231      聯華食品工業股份有限公司      食品工業
# 21       1232         大統益股份有限公司      食品工業
# 22       1233        天仁茶業股份有限公司      食品工業
# 23       1234          黑松股份有限公司      食品工業
# 24       1235        興泰實業股份有限公司      食品工業
# 25       1236        宏亞食品股份有限公司      食品工業
# 26       1256        鮮活控股股份有限公司      食品工業
# 27       1262          綠悅控股有限公司        其他
# 28       1301      台灣塑膠工業股份有限公司      塑膠工業
# 29       1303      南亞塑膠工業股份有限公司      塑膠工業
# ..        ...               ...       ...
# 894      9912        偉聯科技股份有限公司  電腦及週邊設備業
# 895      9914       美利達工業股份有限公司        其他
# 896      9917        中興保全股份有限公司        其他
# 897      9918       欣欣天然氣股份有限公司     油電燃氣業
# 898      9919       康那香企業股份有限公司        其他
# 899      9921      巨大機械工業股份有限公司        其他
# 900      9924      台灣福興工業股份有限公司        其他
# 901      9925      台灣新光保全股份有限公司        其他
# 902      9926        新海瓦斯股份有限公司     油電燃氣業
# 903      9927        泰銘實業股份有限公司        其他
# 904      9928      中國電視事業股份有限公司        其他
# 905      9929        秋雨創新股份有限公司        其他
# 906      9930        中聯資源股份有限公司        其他
# 907      9931       欣高石油氣股份有限公司     油電燃氣業
# 908      9933        中鼎工程股份有限公司        其他
# 909      9934        成霖企業股份有限公司        其他
# 910      9935       慶豐富實業股份有限公司        其他
# 911      9937       全國加油站股份有限公司     油電燃氣業
# 912      9938      台灣百和工業股份有限公司        其他
# 913      9939        宏全國際股份有限公司        其他
# 914      9940      信義房屋仲介股份有限公司        其他
# 915      9941        裕融企業股份有限公司        其他
# 916      9942    茂順密封元件科技股份有限公司        其他
# 917      9943         好樂迪股份有限公司      觀光事業
# 918      9944        新麗企業股份有限公司        其他
# 919      9945      潤泰創新國際股份有限公司        其他
# 920      9946  三發地產股份有限公司(原:金革)      建材營造
# 921      9955      佳龍科技工程股份有限公司        其他
# 922      9958      世紀鋼鐵結構股份有限公司      鋼鐵工業
# 923  合計:共923筆               NaN       NaN
#
#                                        住址    營利事業統一編號                董事長  \
# 0                           台北市中山北路2段113號  11913502.0                張安平
# 1                  台北市大安區敦化南路2段207號30、31樓   3244509.0                徐旭東
# 2                            台北市中山北路2段96號  11892801.0                張剛綸
# 3                        台北市南京東路二段125號10樓   7568009.0                侯博義
# 4                           台北市松江路237號15樓  40601248.0                陳兩傳
# 5                             台北市寶慶路37號7樓   3279507.0                楊智雄
# 6                       高雄市前金區五福三路21號4樓之1  83078600.0                陳敏斷
# 7                              台北市松江路125號  11347802.0                陳永清
# 8                          台北市中山北路二段79號5樓   7067309.0                陳清福
# 9                            台南市永康區蔦松二街三號  73008303.0                韓家宇
# 10                      新北市三重區重陽路三段99號10樓  35012903.0                江國貴
# 11                          台北市松江路八十七號十七樓  36514783.0                鄭武樾
# 12                     71001台南市永康區中正路301號  73251209.0                羅智先
# 13                          嘉義縣民雄鄉工業二路11號  65534366.0                陳哲芳
# 14                            彰化縣田中鎮興工路6號  59661701.0                詹逸宏
# 15                           台中市沙鹿區沙田路45號  56192402.0                洪堯昆
# 16                     台北市中山區南京東路二段206號6樓   3543210.0                陳維讓
# 17                        台中市大肚區沙田路一段453號  22102298.0  晉昇投資有限公司(代表人：許忠明)
# 18                         台北市仁愛路三段136號5樓  22102473.0                曹德風
# 19                  (103)臺北市大同區承德路一段44號6樓  11996904.0                苗豐強
# 20                           台北市迪化街一段148號   7569627.0                李開源
# 21                       台南市官田區二鎮里工業西路32號  20927014.0                羅智先
# 22                        台北市忠孝東路4段107號6樓  18559415.0                李國麟
# 23                         台北市信義路四段296號3樓  20651901.0                張斌堂
# 24                          高雄市仁武區高楠公路10號  85617982.0                吳金泉
# 25                     新北市新店區寶興路45巷8弄3號5樓  34106066.0                張豪城
# 26   P.O. BOX 10338,GRAND CAYMAN KY1-1003  37759808.0                黃國晃
# 27                          臺北市松仁路89號5樓B室  38490560.0                王哲夫
# 28                          高雄市仁武區水管路100號  75708007.0                林健男
# 29                            台北市敦化北路201號  75370905.0                吳嘉昭
# ..                                    ...         ...                ...
# 894                     台北市南港區園區街3之1號五樓之1  20792640.0             俞    允
# 895                      彰化縣大村鄉美港村美港路116號  59052361.0                曾崧柱
# 896                          台北市鄭州路139號6樓  12148598.0                林孝信
# 897                       新北市永和區永和路一段100號  33665843.0                陳何家
# 898                     台南市佳里區民安里同安寮77-1號  74231126.0                戴榮吉
# 899                          台中市大甲區順帆路19號  56054251.0             杜(糸秀)珍
# 900                       高雄市岡山區本洲里育才路88號  75706009.0                林瑞章
# 901                         台北市內湖區行愛路128號  12261768.0                林伯峰
# 902                  新北市三重區力行路一段52號(通訊地址)  35433242.0                謝榮富
# 903                          高雄市大寮區莒光三街六號  79875202.0                陳豊明
# 904                         台北市南港區重陽路118號  18556774.0                邱佳瑜
# 905                    台北市信義區市民大道六段288號9樓  69439272.0                陳慧遊
# 906                 80661高雄市前鎮區成功二路88號22樓  86119908.0                郭新進
# 907                          高雄市鹽埕區大義街56號  79882718.0                陳田錨
# 908                          台北市中山北路六段89號  20817282.0                余俊彥
# 909                 台中市潭子區(台中加工出口區)建國路22號  30899261.0                歐陽明
# 910                       彰化縣福興鄉沿海路四段三七三號  59198197.0                許閔琁
# 911                       台北市羅斯福路六段140號4樓  22958907.0                賴正時
# 912                      彰化縣和美鎮好修里和港路575號   9468343.0                鄭森煤
# 913                            台中市工業區2路6號  58176511.0                戴宏全
# 914                       台北市信義區信義路五段一００號  22354940.0                周俊吉
# 915                        台北市敦化南路二段二號十五樓  23528130.0                陳國榮
# 916                       南投市南崗工業區工業路336號  61904541.0                石正復
# 917                    台北市信義區忠孝東路5段293號4樓  84256265.0                顏瓊章
# 918                          桃園市八德區聯華街41號  33375909.0                簡瑞瑞
# 919                     台北市八德路二段三０八號十一樓之一  12139612.0                簡滄圳
# 920                     台北市松山區八德路3段30號12樓  84466749.0                鍾俊榮
# 921                         桃園市觀音區榮工南路12號  97211972.0                吳界欣
# 922                   桃園市觀音區金湖村中山路一段1119號  22649001.0                賴文祥
# 923                                   NaN         NaN                NaN
#
#                      總經理        發言人       發言人職稱        代理發言人  \
# 0                    李鐘培        黃健強      資深副總經理          蔡立文
# 1                    李坤炎        周維崑        副總經理          吳玲綾
# 2                    祁士鉅        王立心      執行副總經理          余曉芸
# 3                    侯博義        楊宗仁          經理          詹志鴻
# 4                    陳兩傳        溫秀菊       財務部經理          陳一誠
# 5                    楊智雄        吳連富        副總經理          林坤榮
# 6                    吳長直        黃薪翰       財務部經理          唐榮宗
# 7                    蘇守斌        張美凰         財務長            ─
# 8                    陳恭平        魏璟雄          經理          李兆弘
# 9                    莊坤炎        周叔恆          特助          常岡德
# 10                   孫幼英        楊克鳳          經理          洪松輝
# 11                   許瑞通        陳銘龍        特別助理          林明芳
# 12                   侯榮隆        蘇崇銘        副總經理          涂忠正
# 13                   陳志展        陳哲芳         董事長  陳鏡仁 陳志展 蔡慧倫
# 14                   詹景超        林俐婉        副總經理          盧界煥
# 15                   洪堯昆        王四全          特助          李猶龍
# 16                   陳英凱        陳玉能        副總經理          黃棣楨
# 17                   許逸群        陳世章          協理          郭中儀
# 18   YAO STEVEN YIH CHUN        曹德風         執行長          洪佳君
# 19                   景虎士        景虎士         總經理          李富源
# 20                   林家齊        林志遠       財務處協理          陳姵岑
# 21                   陳昭良        陳昭良         總經理          劉信仁
# 22                   林仁宗        莊遠明      執行副總經理          王文嫻
# 23                   張斌堂        白錦文        副總經理      蔡曜光,杜居燦
# 24                   吳金泉        葉文隆       法務處經理          秦慧如
# 25                   張云綺        余彩雲        財務經理          張國振
# 26                   黃國晃        吳明憲          董事          黃永霞
# 27                   王哲夫        蔡如雅       總經理特助          劉桂珍
# 28                   林健男        林勝冠      資深副總經理          張嘉澤
# 29                   鄒明仁        吳嘉昭         董事長          葉明忠
# ..                   ...        ...         ...          ...
# 894                  皮華中        趙欣媛        副總經理          鹿琬為
# 895                  曾崧柱        鄭文祥      行銷本部副總          王隆進
# 896                小野寺博史        蘇盈彰        副總經理          湯敦台
# 897                  王天德        廖江津        副總經理          簡益信
# 898                  戴秀玲        林秀娟       稽核處主管          吳政蓉
# 899                  劉湧昌        李書耕  全球公關暨行銷負責人          陳美惠
# 900                  陳建昆        李國偉         財務長          蔡燕芬
# 901                  洪國超        黃春明        副總經理          鄒國民
# 902                  游明俊        張志雄        副總經理          李振隆
# 903                  李茂生        童新沅       財會部經理          李淑芬
# 904                  胡雪珠        胡雪珠         總經理          陳淑雯
# 905                  謝志達        陳延暉        法務主管          張麗珠
# 906                  蔡沛宏        金崇仁        副總經理          林清安
# 907                  陳建東        萬家驊       董事會秘書          黃羅慧
# 908                  楊宗興        蕭銘證        副總經理          林盟智
# 909         ANDREW YATES        陳宗民       集團財務長          石乃菁
# 910                  許竣然        許竣然         總經理          黃惠萍
# 911                  蔡佳璋        蔡佳璋         總經理          林玉儷
# 912                  鄭誠禕        葉桂珠        副總經理          葉淑惠
# 913                  曹世忠        顏清權      總管理處協理          盧麒伊
# 914                  劉元智        周莊雲         策略長          陳志桓
# 915                  許國興        莊文凱   行政管理處資深協理          廖淑華
# 916                  石銘耀        薛汝青       財務部經理          陳玉琴
# 917                  鄭景文        李俊德       財務處協理          李易翰
# 918                  簡裘裘        簡裘裘         總經理          施中南
# 919                  李志宏        簡滄圳         董事長          葉天政
# 920                  鍾俊榮  代理發言人 洪振耀      執行副總經理          洪振耀
# 921                  吳界欣        陸怡豪        策略顧問          張國樑
# 922                  陳志昌        李育慶       業務部協理          朱益輝
# 923                  NaN        NaN         NaN          NaN
#
#                   ...                 特別股  編制財務報表類型            股票過戶機構  \
# 0                 ...                 0.0       1.0       中國信託商業銀行代理部
# 1                 ...                 0.0       1.0        亞東證券股份有限公司
# 2                 ...                 0.0       1.0   群益金鼎證券股份有限公司股代部
# 3                 ...                 0.0       1.0   凱基證券股份有限公司股務代理部
# 4                 ...                 0.0       1.0         永豐金證券股務代理
# 5                 ...                 0.0       1.0       中國信託商業銀行代理部
# 6                 ...                 0.0       1.0        元大證券股份有限公司
# 7                 ...                 0.0       1.0         元大證券股務代理部
# 8                 ...                 0.0       1.0      群益金鼎證券股份有限公司
# 9                 ...                 0.0       1.0       中國信託商業銀行代理部
# 10                ...                 0.0       1.0       大西洋飲料股份有限公司
# 11                ...                 0.0       1.0       中國信託商業銀行代理部
# 12                ...                 0.0       1.0  統一綜合證券(股)公司股務代理部
# 13                ...                 0.0       1.0      群益金鼎證券股份有限公司
# 14                ...                 0.0       1.0        元大證券股份有限公司
# 15                ...                 0.0       1.0        凱基證券股份有限公司
# 16                ...                 0.0       1.0       中國信託商業銀行代理部
# 17                ...                 0.0       1.0      群益金鼎證券股份有限公司
# 18                ...                 0.0       1.0       中國信託商業銀行代理部
# 19                ...                 0.0       1.0       中國信託商業銀行代理部
# 20                ...                 0.0       1.0       永豐金證券股份有限公司
# 21                ...                 0.0       1.0      統一綜合證券股份有限公司
# 22                ...                 0.0       1.0        元大證券股份有限公司
# 23                ...                 0.0       1.0   宏遠證券股份有限公司股務代理部
# 24                ...                 0.0       1.0      國票綜合證券股份有限公司
# 25                ...                 0.0       1.0      群益金鼎證券股份有限公司
# 26                ...                 0.0       1.0   兆豐證券股份有限公司股務代理部
# 27                ...                 0.0       1.0   凱基證券股份有限公司股務代理部
# 28                ...                 0.0       1.0            本公司股務組
# 29                ...                 0.0       1.0            本公司股務組
# ..                ...                 ...       ...               ...
# 894               ...                 0.0       1.0      群益金鼎證券股份有限公司
# 895               ...                 0.0       1.0        元大證券股份有限公司
# 896               ...                 0.0       1.0        元大證券股份有限公司
# 897               ...                 0.0       1.0   凱基證券股份有限公司股務代理部
# 898               ...                 0.0       1.0   凱基證券股份有限公司股務代理部
# 899               ...                 0.0       1.0        福邦證券股份有限公司
# 900               ...                 0.0       1.0      群益金鼎證券股份有限公司
# 901               ...                 0.0       1.0    元富證券(股)公司股務代理部
# 902               ...                 0.0       1.0   元富證券股份有限公司股務代理部
# 903               ...                 0.0       1.0     台新國際商業銀行股務代理部
# 904               ...                 0.0       1.0        凱基證券股份有限公司
# 905               ...                 0.0       1.0        元大證券股份有限公司
# 906               ...                 0.0       1.0        凱基證券股份有限公司
# 907               ...                 0.0       1.0      群益金鼎證券股份有限公司
# 908               ...                 0.0       1.0        凱基證券股份有限公司
# 909               ...                 0.0       1.0       永豐金證券股份有限公司
# 910               ...                 0.0       1.0      群益金鼎證券股份有限公司
# 911               ...                 0.0       2.0        元大證券股份有限公司
# 912               ...                 0.0       1.0       中國信託商業銀行代理部
# 913               ...                 0.0       1.0        凱基證券股份有限公司
# 914               ...                 0.0       1.0  群益金鼎證券(股)公司股務代理部
# 915               ...                 0.0       1.0     裕融企業股份有限公司股務室
# 916               ...                 0.0       1.0        元大證券股份有限公司
# 917               ...                 0.0       1.0        福邦證券股份有限公司
# 918               ...                 0.0       1.0       中國信託商業銀行代理部
# 919               ...                 0.0       1.0            本公司股務室
# 920               ...                 0.0       1.0        元大證券股份有限公司
# 921               ...                 0.0       1.0        元富證券股份有限公司
# 922               ...                 0.0       1.0      群益金鼎證券股份有限公司
# 923               ...                 NaN       NaN               NaN
#
#               過戶電話                       過戶地址             英文簡稱  \
# 0         66365566             台北市重慶南路一段83號5樓              TCC
# 1     02-2361-8608             台北市重慶南路一段86號3樓              ACC
# 2    (02)2702-3999           台北市敦化南路2段97號地下2樓              CHC
# 3      02-23892999         ﹝100﹞台北市重慶南路一段2號5樓              UCC
# 4        2381-6288             台北市中正區博愛路17號3樓     LUCKY CEMENT
# 5    (02)6636-5566             台北巿重慶南路一段83號5樓          HsingTa
# 6      02-25865859          台北市承德路三段210號地下室1樓      TUNA CEMENT
# 7     (02)25865859        台北市大同區承德路3段210號地下一樓        Wei Chuan
# 8         27023999           台北市敦化南路二段97號地下2樓          VE WONG
# 9      02-66365566            台北市重慶南路一段八十三號六樓        GREATWALL
# 10   (02)2982-0061          新北市三重區重陽路三段99號10樓                N
# 11     02-66365566            台北市重慶南路一段八十三號五樓              CPE
# 12   (02)2746-3797  10570台北市松山區東興路8號統一大樓地下室一樓    UNI-PRESIDENT
# 13     02-27023999        台北市大安區敦化南路二段97號地下二樓              AGV
# 14     02-25865859             台北市承德路三段210號B1           TAISUN
# 15     02-23892999         100台北市重慶南路一段2號5樓��           FWUSOW
# 16    (02)66365566             台北市重慶南路一段83號5樓          TAIROUN
# 17     02-27023999           台北市敦化南路二段97號地下二樓            FOPCO
# 18   (02)6636-5566             台北市重慶南路一段83號5樓            S.F.C
# 19   (02)6636-5566             台北市重慶南路一段83號5樓             LHIC
# 20    (02)23816288                台北市博愛路17號3樓   Lian Hwa Foods
# 21    02-2746-3797               台北市東興路8號地下一樓             TTET
# 22     02-25865859           台北市承德路3段210號地下一樓          Ten Ren
# 23   (02)7719-8899          台北市大安區信義路四段236號3樓         HEY-SONG
# 24     02-25936666       10369台北市重慶北路3段199號4樓               ST
# 25   (02)2702-3999        台北市大安區敦化南路2段97號地下2樓            Hunya
# 26     02-33930398             台北市忠孝東路二段95號1樓         Sunjuice
# 27    02-2389-2999              台北市重慶南路一段2號5樓       Green Seal
# 28   (02)2718-9898            台北市敦化北路201號後棟1樓              FPC
# 29        27189898            台北市敦化北路201號後棟一樓              NPC
# ..             ...                        ...              ...
# 894    02-27023999         台北市大安區敦化南二段97號地下二樓              AIC
# 895  (02) 25865859     (103)臺北市大同區承德路3段210號B1              MIC
# 896   02-2586-5859          台北市大同區承德路三段210號B1     TAIWAN SECOM
# 897       23892999              台北市重慶南路一段二號五樓          S.S.N.G
# 898  (02)2389-2999              台北市重慶南路一段二號五樓              KNH
# 899   (02)23711658           台北市中正區忠孝西路一段６號６樓            GIANT
# 900   02-2702-3999     (106大安區)台北巿敦化南路2段97號B2  TAIWAN FU HSING
# 901   02-2768-6668       台北市松山區光復北路11巷35號地下一樓              SKS
# 902  (02)2768-6668       台北市松山區光復北路11巷35號地下一樓             S.H.
# 903  (02)2504-8125           台北市建國北路一段96號地下一樓              TMI
# 904  02- 2389-2999              台北市重慶南路一段2號5樓              CTV
# 905  (02)2586-5859        台北市大同區承德路三段210號地下一樓           CHOICE
# 906  (02)2389-2999              台北市重慶南路一段2號4樓              CHC
# 907    02-27023999          台北市大安區敦化南路二段97號B2         HSIN KAO
# 908  (02)2389-2999              台北市重慶南路一段2號5樓             CTCI
# 909    02-23816288             台北市中正區博愛路17號3樓             GUIC
# 910    02-27035000         台北市大安區敦化南路二段九十七號B2               CF
# 911  (02)2586-5859       103台北市大同區承德路三段210號B1              NPC
# 912    02-66365566             台北市重慶南路一段83號5樓     TAIWAN PAIHO
# 913    02-23148800              台北市重慶南路一段2號5樓        HON CHUAN
# 914       27035000             台北市敦化南路二段97號B2     Sinyi Realty
# 915      2515-6421            台北市南京東路二段150號7樓              TAC
# 916  (02)2586-5859          台北市大同區承德路三段210號B1         MAO SHUN
# 917  (02)2371-1658           台北市中正區忠孝西路一段６號６樓          HOLIDAY
# 918  (02)6636-5566             台北市重慶南路一段83號5樓           Shinih
# 919       81619888            台北市八德路二段三０八號十二樓  RUENTEX DEVELOP
# 920       25865859          台北市大同區承德路3段210號B1          SanFar
# 921  (02)2768-6668      105台北市松山區光復北路11巷35號B1            SDTI
# 922  (02)2702-3999       台北市106大安區敦化南路二段97號B2           CIAS
# 923            NaN                        NaN              NaN
#
#                                                 英文通訊地址          傳真機號碼  \
# 0    No.113, Sec.2, Zhongshan N. Rd.,Taipei City 10...  (02)2531-6529
# 1    30TH FLOOR,TAIPEI METRO TOWER,207.TUN HWA SOUT...   02-2378-5191
# 2    No.96, Sec. 2, Zhongshan N. Rd., Zhongshan Dis...  (02)2511-4002
# 3      10th F1., 125 Nanking E.Rd Sec. 2,Taipei Taiwan    02-25075870
# 4    15TH FL.,NO.237,SUNG KIANG RD.,TAIPEI,TAIWAN,R...       25048672
# 5     7TH FL.,No.37 Pao Ching RoadTaipei Taiwan R.O.C.       23314086
# 6          NO.21 Wu Fu 3 RoadKaohsiung, Taiwan, R.O.C.     07-9505895
# 7    10F., No.125, Sung Chiang Rd.Taipei, Taiwan(R....   (02)25063182
# 8    5TH FL., 79 CHUNG SHAN N. RD., SEC.2TAIPEI TAIWAN   (02)25811006
# 9     3 NIAOSUN 2TH STREETYONGKONG TAINAN CONTY TAIWAN     06-2534596
# 10   10F,99,Sec.3,Chung Yang Road,San Chung City,Ta...  (02)2984-1154
# 11        17F., 87 Sung Chiang Road,Taipei, Taiwan 104    02-25064137
# 12   No.301, Zhongzheng Rd., Yongkang Dist.,Tainan ...   (06)253-2661
# 13   NO.11,Kung Yeh Second Rd.,Min Hsiong Industria...     05-2216287
# 14   No.6, Xinggong Rd., Tianzhong Township.Changhu...     04-8758989
# 15             45,Sha-Tyan,Sha-LuTaichung Taiwan R.O.C    04-26358452
# 16   6TH FL. NO. 206.  NANKING E. RD., SEC. 2Taipei...  (02)2507-7020
# 17   3RD FL,150 NANKING EAST RD, SEC.2 TAIPEI TAIWA...   (02)25071312
# 18   5th Floor, Lotus Building,No.136, Jen Ai Road,...      2706-7955
# 19   6F., No.44, Sec. 1, Chengde Rd., Datong Distri...  (02)2786-3232
# 20         148 TI HWA STREET SEC.1,Taipei,Taiwan,R.O.C   (02)25533479
# 21   32, Gongye West Road, Erzhen Village, Guantian...    06-698-5530
# 22   6F. NO.107,SEC 4, Chung Hsiao East Road,Taipei...    02-27403035
# 23   3RD FL. NO. 296, SEC. 4, HSIN YI RD.TAIPEI, TA...  (02)2755-2119
# 24   10 KAO-NANG HIGHWAYJEN-WUH KAOHSIUNG TAIWAN R....     07-3425694
# 25   3,Alley8,Lane45,Pao Hsin Rd;Hsin Tien,Taipei,T...   (02)29180706
# 26   P.O. BOX 10338,GRAND CAYMAN KY1-1003Grand Caym...   512-57515503
# 27   Room B, 5F, 89 Songren Road, Xinyi DistrictTai...     0287890623
# 28   4F, 201, Tung Hwa North RoadTaipei, Taiwan, R....  (02)2717-8108
# 29   201, TUNG HWA NORTH ROADTAIPEI TAIWAN, REPUBLI...       27178533
# ..                                                 ...            ...
# 894  5F-1, No. 3-1, Park Street, Nangang District, ...    02-26557878
# 895  NO. 116 MEGAN ROAD,DACUN TOWNSHIPCHANGHUA COUN...    (04)8527881
# 896             NO.139,6F,CHENG-CHOU RD.,TAIPEI,TAIWAN       25571115
# 897  No.100 Sec.1 Yung-Ho RoadYung-Ho Dist,New Taip...       29253004
# 898        27th F1.,456,Sinyi Road,Sec.4Taipei, Taiwan  (02)2345-6299
# 899  19,SHUN-FARN ROAD DAJIA DISTRICT,TAICHUNG CITY...   (04)26810280
# 900  No.88, YUCAI RDKANGSHAN, KAOHSIUNG CITY, TAIWA...     07-6225466
# 901  No.128, Xing’ai Rd., Neihu DistTAIPEI,TAIWAN,R...    02-27908573
# 902  No.52, SECTION 1, LI-SHING ROAD, SAN CHUNG DIS...  (02)2982-6901
# 903  NO.6,Chu Kuang 3rd StDaliao Dist, Kaohsiung Ci...   (07)787-3496
# 904                118,Chung-Yang RoadTaipe,Taiwan,ROC  (02)2796-5284
# 905  9F, No.288, Sec. 6, Civic Blvd.,  Taipei City ...   (02)87681966
# 906  22F,No.88,Chenggong 2nd Rd.,Qian-Zhen,Kaohsiun...   (07)336-8433
# 907  56,TA-YI ST.YEN CHENG DIST.KAOHSIUNG, TAIWAN R...      075312932
# 908  89, Sec. 6, Zhongshan North RoadTAIPEI, TAIWAN...  (02)2833-8899
# 909  22,Chien-Kuo Rd.Taichung Export Processing Zon...    04-25340840
# 910  373. SEC.  4, YEN-HAI  RD, FU-NAN VILLAGEFU HS...     04-7707789
# 911  4F,No.140,Sec.6,Roosevelt Road,Taipei,Taiwan,R...  (02)2935-6505
# 912  NO.575,HO KANG RD.HO MEI TOWNCHANG HUA SHIEN,T...     04-7570670
# 913  NO.6,2ND.ROAD,INDUSTRIAL PARKTAICHUNG TAIWAN,R...    04-23590086
# 914             No.100, SEC.5, SINYI ROADTAIPEI,TAIWAN       27228169
# 915        15F,2,Tun Hua South Road,Sec.2Taipei,Taiwan      2702-9347
# 916  NO 336 INDUSTRIAL ROAD., NANKANG INDUSTRIAL ZO...  (049)2255-401
# 917  4th Floor Zhongxiao East Road, Xinyi District,...  (02)2769-6607
# 918  No.41, Lianhua StBade Dist., Taoyuan City 334,...    (03)3650973
# 919  11/F,No.308,Section 2, Bade Road,Taipei,Taiwan...       81617968
# 920  12F, No.30,sec.3,Bode  RD.Songshan District.,T...      2570-6985
# 921     No.12,Rung-Kung S. STTao-Yuan 328, Taiwan,ROC　   (03)473-5259
# 922  No.1119,Sec.1,Zhongshan Rd.,Guanyin Shiang,Tao...     03-4738325
# 923                                                NaN            NaN
#
#                                             電子郵件信箱  \
# 0                         finance@taiwancement.com
# 1                               service@acc.com.tw
# 2               investor-relations@chcgroup.com.tw
# 3                                    ucc@ucctw.com
# 4                            wendy@luckygrp,com.tw
# 5                           service@hsingta.com.tw
# 6                           southeast@secement.com
# 7                          service@weichuan.com.tw
# 8                                wei@vewong.com.tw
# 9                         john@greatwall-group.com
# 10                         c5012903@ms23.hinet.net
# 11                            service@cptwn.com.tw
# 12                           jlian@mail.pec.com.tw
# 13                          a11369@mail.agv.com.tw
# 14                           taisun1@taisun.com.tw
# 15                            fwusow@fwusow.com.tw
# 16                         glen6572@tairoun.com.tw
# 17                         cherry.lin@fopco.com.tw
# 18                   spokesperson1@sfworldwide.com
# 19                                info@lhic.com.tw
# 20                           tomlin@lianhwa.com.tw
# 21                        finance@mail.ttet.com.tw
# 22                         chafortea@tenren.com.tw
# 23                          heysong@heysong.com.tw
# 24                         shintai1235@seed.net.tw
# 25                                    hunya.com.tw
# 26                              XH@sunjuice.com.cn
# 27                 bonnie.tsai@greenseal-group.com
# 28                              formosa@fpc.com.tw
# 29                                nanya@npc.com.tw
# ..                                             ...
# 894                                              N
# 895                          bicycle@merida.com.tw
# 896                        CHENSHUFEN@SECOM.COM.TW
# 897                        ssngasll@ms67.hinet.net
# 898                    christine.wu@knh-global.com
# 899                          Sandylin@giant.com.tw
# 900                         stephen@fuhsing.com.tw
# 901  TSUNGHSIEN.WENG@SKS.COM.TW;0086996@sks.com.tw
# 902                      service@shinhaigas.com.tw
# 903                         financial@tmicl.com.tw
# 904                     091002@mail.chinatv.com.tw
# 905                       job@choicecompany.com.tw
# 906                                 avo@chc.com.tw
# 907                      hsinkao.gas@msa.hinet.net
# 908                         karencheng@ctci.com.tw
# 909                                              -
# 910                             ping@chingfeng.com
# 911                            peggy@npcgas.com.tw
# 912                              finance@paiho.com
# 913                     emily@mail.honchuan.com.tw
# 914                           S209311@SINYI.COM.TW
# 915                            may.liao@tac.com.tw
# 916                          simon@mail.nak.com.tw
# 917                              ir@holiday.com.tw
# 918                      fisher.chen@shinih.com.tw
# 919                        cmc@mail.ruentex.com.tw
# 920                          contact@sanfar.com.tw
# 921                            service@sdti.com.tw
# 922                      ct.service@century.com.tw
# 923                                            NaN
#
#                                  網址
# 0        http://www.taiwancement.com
# 1                     www.acc.com.tw
# 2                www.chcgroup.com.tw
# 3                      www.ucctw.com
# 4                www.luckygrp.com.tw
# 5                 www.hsingta.com.tw
# 6         www.southeastcement.com.tw
# 7         http://www.weichuan.com.tw
# 8              http://www.vewong.com
# 9              http://www.dachan.com
# 10      http://www.applesidra.com.tw
# 11           http://www.cptwn.com.tw
# 12   http://www.uni-president.com.tw
# 13                    www.agv.com.tw
# 14                 www.taisun.com.tw
# 15                 www.fwusow.com.tw
# 16        http://www.tairoun.com.tw/
# 17                  WWW.FOPCO.COM.TW
# 18       http://www.sfworldwide.com/
# 19            http://www.lhic.com.tw
# 20                www.lianhwa.com.tw
# 21            http://www.ttet.com.tw
# 22         http://www.tenren.com.tw/
# 23                www.heysong.com.tw
# 24           www.shintai-feed.com.tw
# 25                  www.hunya.com.tw
# 26       http://www.myfreshjuice.com
# 27           www.greenseal-group.com
# 28             http://www.fpc.com.tw
# 29             http://www.npc.com.tw
# ..                               ...
# 894          http://www.agneovo.com/
# 895                www.merida.com.tw
# 896                 WWW.SECOM.COM.TW
# 897    http://www.shinshingas.com.tw
# 898   http://www.knh.com.tw/main.php
# 899    http://www.giant-bicycles.com
# 900               www.fuhsing.com.tw
# 901                   www.sks.com.tw
# 902    http://www.shinhaigas.com.tw/
# 903                 www.tmicl.com.tw
# 904                   www.ctv.com.tw
# 905  http://www.choicecompany.com.tw
# 906                   www.chc.com.tw
# 907                 www.hkgas.com.tw
# 908                  www.ctci.com.tw
# 909               www.globeunion.com
# 910         http://www.chingfeng.com
# 911         http://www.npcgas.com.tw
# 912             http://www.paiho.com
# 913       http://www.honchuan.com.tw
# 914                 WWW.SINYI.COM.TW
# 915            http://www.tac.com.tw
# 916                   www.nak.com.tw
# 917               www.holiday.com.tw
# 918                www.shinih.com.tw
# 919            www.rt-develop.com.tw
# 920          www.sanfarproperty.com/
# 921                  www.sdti.com.tw
# 922               www.century.com.tw
# 923                              NaN
#
# [924 rows x 26 columns]

# %% [markdown]
# # Q4. 畫出技術曲線
#
# 請畫出除了上課提過的線型之外的任何技術曲線，並寫註解說明。

# %%
# 匯入資料
df1 = data['AAPL']

# %%
# 計算 MACD
df1['DIF'] = pd.Series.ewm(df1['Close'],span=12,min_periods=1).mean()-pd.Series.ewm(df1['Close'],span=26,min_periods=1).mean()
df1['DEA'] = pd.Series.ewm(df1['DIF'],span=9,min_periods=1).mean()
df1['MACD'] = (df1['DIF']-df1['DEA'])*2

# %%
# 分別畫出DIF.DEA與MACD兩張圖並合併
plt.figure()
ax = df1[['MACD']].plot(kind="bar",color='g');plt.xticks(rotation=0)
ax2 = ax.twinx()
ax2.plot(ax.get_xticks(),df1[['DIF', 'DEA']])
# Out:
# [<matplotlib.lines.Line2D at 0x21f820dbcf8>,
#  <matplotlib.lines.Line2D at 0x21f820d2c50>]

# %% [markdown]
# # Q5. 策略回測

# %%
# 計算 MaxDD
def DrawDownAnalysis(cumRet):
    dd_series = ffn.core.to_drawdown_series(cumRet)
    dd_details = ffn.core.drawdown_details(dd_series)
    return dd_details['drawdown'].min(), dd_details['days'].max()

# %%
# 利用策略產生的持有部位資訊，計算底下四個指標來判斷投資績效
# sharpe ratio: 判斷報酬的好壞跟穩定度，數值越大越好
# maxdd: maximum drawdown, 最糟糕的狀況會賠幾 %
# maxddd: maximum drawdown duration, 低於上一次最高報酬的天數
# cumRet[-1]: 最後賺的 % 數

def indicators(df):
    dailyRet = df['Close'].pct_change()
    excessRet = (dailyRet - 0.04/252)[df['positions'] == 1]
    SharpeRatio = np.sqrt(252.0)*np.mean(excessRet)/np.std(excessRet)
    
    cumRet = np.cumprod(1+excessRet)
    
    maxdd, maxddd = DrawDownAnalysis(cumRet)
    
    return SharpeRatio, maxdd, maxddd, cumRet[-1]

# %%
# 這是我們的策略的部分
# 主要只是要算出進出的訊號 signals 跟何時持有部位 positions
# 底下是一個突破系統的範例

def Breakout_strategy(df):
    # Donchian Channel
    df['20d_high'] = np.round(pd.Series.rolling(df['Close'], window=20).max(), 2)
    df['10d_low'] = np.round(pd.Series.rolling(df['Close'], window=10).min(), 2)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] > df['20d_high'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] < df['10d_low'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def RSI_7030_strategy(df):
    df['RSI'] = talib.RSI(df['Close'].values)
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['RSI'][t-1] < 30:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['RSI'][t-1] > 70:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def BBands_strategy(df):
    df['UBB'], df['MBB'], df['LBB'] = talib.BBANDS(df['Close'].values, matype=MA_Type.T3)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] < df['LBB'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] > df['UBB'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
# MACD: 進場條件:DIF.DEA皆小於 0 且 黃金交叉
#       出場條件:DIF.DEA皆大於 0 且 死亡交叉

def M064030013_strategy(df):
    df['DIF'] = pd.Series.ewm(df['Close'],span=12,min_periods=1).mean()-pd.Series.ewm(df['Close'],span=26,min_periods=1).mean()
    df['DEA'] = pd.Series.ewm(df['DIF'],span=9,min_periods=1).mean()
    df['MACD'] = (df['DIF']-df['DEA'])*2
    
    has_position = False
    df['signals'] = 0
    
    for t in range(2, df['signals'].size):
            if df['DIF'][t] > df['DEA'][t] and df['DIF'][t-1] < df['DEA'][t-1] and df['DIF'][t] < 0 and df['DEA'][t] < 0:
                if not has_position:
                    df.loc[df.index[t], 'signals'] = 1
                    has_position = True
            elif df['DIF'][t] < df['DEA'][t] and df['DIF'][t-1] > df['DEA'][t-1] and df['DIF'][t] > 0 and df['DEA'][t] > 0:
                if has_position:
                    df.loc[df.index[t], 'signals'] = -1
                    has_position = False
                    
    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def apply_strategy(strategy, df):
    return strategy(df)

# %%
# 計算各支股票的回測結果
results = []

#strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy, 學號_strategy]
strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy,M064030013_strategy]

for symbol in data:
    for strategy in strategies:
        try:
            apply_strategy(strategy, data[symbol])
            if np.all(data[symbol]['signals']==0):
                print("Symbol:", symbol, "使用", strategy.__name__, "策略沒有出現買賣訊號。")
                continue
            SharpeRatio, maxdd, maxddd, finalRet = indicators(data[symbol])
            days = (data[symbol].index[-1] - data[symbol].index[0]).days
            results.append((SharpeRatio, maxdd, maxddd, finalRet, days,
                            data[symbol][data[symbol]['signals'] > 0]['signals'].sum(), symbol, strategy.__name__))
        except Exception as e:
            print("Error occurs at symbol:", symbol, "Strategy:", strategy.__name__, "==>", e.args)

# %%
results_df = pd.DataFrame(results, columns=['sharpe','MaxDrawDown','MaxDrawDownDuration','returns', 
                                            'days', 'entries','symbol','strategy'])

# %%
results_df.head()
# Out:
#      sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries symbol  \
# 0  0.131503    -0.208296                  281  0.995734   705       11   TICC
# 1  0.395515    -0.244817                  482  1.077756   705        2   TICC
# 2  0.102787    -0.231763                  426  0.984521   705       20   TICC
# 3  0.629635    -0.163074                  356  1.119011   705        8   TICC
# 4  1.365570    -0.361485                  299  1.631388   705       12   TWIN
#
#               strategy
# 0    Breakout_strategy
# 1    RSI_7030_strategy
# 2      BBands_strategy
# 3  M064030013_strategy
# 4    Breakout_strategy

# %%
results_df.sort_values('MaxDrawDown',ascending=False).head()
# Out:
#        sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 73   6.306176    -0.003654                  122  1.028222   473        3
# 17  10.243474    -0.006251                    3  1.132402   705        1
# 74   2.038551    -0.013673                  119  1.060527   473       16
# 66   1.085572    -0.023454                  135  1.049505   384       12
# 36   3.040178    -0.023844                   58  1.073352   203        3
#
#    symbol           strategy
# 73    LCA  RSI_7030_strategy
# 17   GOOG  RSI_7030_strategy
# 74    LCA    BBands_strategy
# 66   SCAC    BBands_strategy
# 36   CSML  Breakout_strategy

# %%
results_df.sort_values('returns',ascending=False).head()
# Out:
#       sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 9   2.013777    -0.219296                  167  2.477803   705        4
# 14  2.062962    -0.286661                  113  2.422460   705       22
# 78  2.136744    -0.454342                  191  2.400221   705       21
# 5   2.424484    -0.169115                  115  2.151881   705        3
# 7   2.219829    -0.171718                  229  1.900586   705        7
#
#    symbol             strategy
# 9    AMOT    RSI_7030_strategy
# 14   CDZI      BBands_strategy
# 78   BBGI      BBands_strategy
# 5    TWIN    RSI_7030_strategy
# 7    TWIN  M064030013_strategy
